# %%
import networkx as nx
import matplotlib.pyplot as plt
from SinglePushout import SinglePushout

# %%
sp = SinglePushout()

# %%
sp.add_edge_L("A", "B")
sp.add_edge_R("A", "E")  
sp.add_edge_R("E", "B")

# %%
pos = nx.spring_layout(sp.graph_L)
nx.draw(sp.graph_L, pos, with_labels=True, node_size=700, node_color="lightblue")

# %%
sp.display_graph(sp.graph_L)

# %%
sp.shared_nodes = ({'A', 'B'})

# %%
pushout_graph = sp.compute_pushout()

# %%
sp.find_shared_nodes()

# %%
sp.display_graph(pushout_graph)
